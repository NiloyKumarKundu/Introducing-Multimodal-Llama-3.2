# %% [markdown]
# # Llama 3.2 Multimodal Prompting

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from utils import load_env
load_env()

# %% [markdown]
# ## Text input only question

# %%
from utils import llama32
from utils import llama31

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>utils.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %%
messages = [
  {"role": "user",
    "content": "Who wrote the sharlock holmes books?"}
]

# %%
response_32 = llama32(messages, 90)
print(response_32)
# Out:
# The Sherlock Holmes books were written by Sir Arthur Conan Doyle, a Scottish physician and writer. Doyle wrote four novels and 56 short stories featuring the iconic detective Sherlock Holmes, with the first story, "A Study in Scarlet," published in 1887.
#
# Here are the four novels:
#
# 1. "A Study in Scarlet" (1887)
# 2. "The Sign of Four" (1890)
# 3. "The Hound of the Baskervilles" (1902)
# 4. "The Valley of Fear" (1915)
#
# And here are the short story collections:
#
# 1. "The Adventures of Sherlock Holmes" (12 stories, 1892)
# 2. "The Memoirs of Sherlock Holmes" (12 stories, 1894)
# 3. "His Last Bow: Some Later Reminiscences of Sherlock Holmes" (7 stories, 1917)
# 4. "The Case-Book of Sherlock Holmes" (12 stories, 1927)
#
# Sir Arthur Conan Doyle's stories have been widely popular and have been adapted into numerous films, plays, and TV shows, cementing Sherlock Holmes' place as one of the most iconic fictional characters of all time.

# %%
response_31 = llama31(messages,70)
print(response_31)
# Out:
# The Sherlock Holmes books were written by Sir Arthur Conan Doyle. He was a Scottish physician and writer who created the iconic character of Sherlock Holmes, a detective who solves crimes in London with his trusty sidekick, Dr. John Watson. Doyle wrote four novels and 56 short stories featuring Sherlock Holmes, including:
#
# 1. "A Study in Scarlet" (1887)
# 2. "The Sign of Four" (1890)
# 3. "The Hound of the Baskervilles" (1902)
# 4. "The Valley of Fear" (1915)
#
# The short stories were collected in five volumes:
#
# 1. "The Adventures of Sherlock Holmes" (1892)
# 2. "The Memoirs of Sherlock Holmes" (1894)
# 3. "His Last Bow: Some Later Reminiscences of Sherlock Holmes" (1917)
# 4. "The Case-Book of Sherlock Holmes" (1927)
# 5. "The Return of Sherlock Holmes" (1905)
#
# Doyle's stories have been widely popular and have been adapted into numerous films, plays, and television shows, cementing Sherlock Holmes' place as one of the most iconic characters in literature.

# %% [markdown]
# ## Reprompting with new question

# %%
messages = [
  {"role": "user",
    "content": "Who wrote the sharlock holmes books?"},
      {"role": "assistant",
    "content": response_32},
      {"role": "user",
    "content": "3 of the best quotes"}
]

# %%
response_32 = llama32(messages,90)
print(response_32)
# Out:
# Here are three of the most iconic and thought-provoking quotes from the Sherlock Holmes stories:
#
# 1. **"Elementary, my dear Watson."**
#
# From: "The Crooked Man" (1893)
#
# This quote has become synonymous with Sherlock Holmes' incredible deductive abilities and his tendency to make complex conclusions seem obvious. It's a phrase that has been parodied and referenced countless times in popular culture.
#
# 2. **"It is a capital mistake to theorize before one has data. Insensibly one begins to twist facts to suit theories, instead of theories to suit facts."**
#
# From: "A Study in Scarlet" (1887)
#
# This quote highlights Sherlock Holmes' scientific approach to detective work and his emphasis on gathering data before forming conclusions. It's a valuable lesson in critical thinking and the importance of separating facts from assumptions.
#
# 3. **"The game is afoot!"**
#
# From: "The Abbey Grange" (1904)
#
# This quote captures the excitement and energy of the chase, as Sherlock Holmes sets out to solve a new case. It's a phrase that has become synonymous with the thrill of the hunt and the intellectual puzzle-solving that lies at the heart of the Sherlock Holmes stories.
#
# I hope you enjoy these quotes!

# %%
response_31 = llama31(messages,70)
print(response_31)
# Out:
# Here are three of the most famous and iconic quotes from the Sherlock Holmes stories:
#
# 1. **"Elementary, my dear Watson."** - This quote, often misquoted as "Elementary, my dear fellow," is one of the most famous lines from the Sherlock Holmes stories. It's a phrase that Holmes uses to explain the simplicity of a solution to a complex problem.
#
# 2. **"It is a capital mistake to theorize before one has data. Insensibly one begins to twist facts to suit theories, instead of theories to suit facts."** - This quote highlights Holmes' emphasis on the importance of gathering data and evidence before forming theories or conclusions.
#
# 3. **"The game is afoot!"** - This quote is a phrase that Holmes uses to signal the start of an investigation or a new case. It's a phrase that has become synonymous with the excitement and energy of the detective's work.
#
# These quotes capture the essence of Sherlock Holmes' character and his approach to detective work, and have become an integral part of popular culture.

# %% [markdown]
# ## Question about an image

# %%
from utils import disp_image

# %%
disp_image("images/Llama_Repo.jpeg") # Example usage for local image

# %% [markdown]
# ### Image from a URL

# %%
image_url = ("https://raw.githubusercontent.com/meta-llama/"
            "llama-models/refs/heads/main/Llama_Repo.jpeg")
messages = [
  {"role": "user",
    "content": [
      {"type": "text",
        "text": "describe the image in one sentence"
      },
      {"type": "image_url",
        "image_url": {"url": image_url}
      }
    ]
  },
]

# %%
disp_image(image_url)
result = llama32(messages,90)
print(result)
# Out:
# The image depicts three llamas, one of which is purple and wearing a party hat, standing behind a table with a glass of beer on it.

# %% [markdown]
# ### Using a local image

# %%
import base64

def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')
base64_image = encode_image("images/Llama_Repo.jpeg")

# %%
messages = [
  {"role": "user",
    "content": [
      {"type": "text",
        "text": "describe the image in one sentence"
      },
      {"type": "image_url",
        "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}
      }
    ]
  },
]

# %%
disp_image(image_url)
result = llama32(messages,90)
print(result)
# Out:
# The image depicts three llamas, one of which is wearing a party hat, sitting at a table with a glass of orange liquid.

# %% [markdown]
# ## Follow up question about an image

# %%
messages = [
  {"role": "user",
    "content": [
      {"type": "text",
        "text": "describe the image in one sentence"
      },
      {"type": "image_url",
        "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}
      }
    ]
  },
  {"role": "assistant", "content": result},
  {"role": "user", "content": "how many of them are purple?"}
]

# %%
result = llama32(messages)
print(result)
# Out:
# One of the llamas is purple.

# %% [markdown]
# ### Define llama32pi() helper

# %%
def llama32pi(prompt, image_url, model_size=90):
  messages = [
    {
      "role": "user",
      "content": [
        {"type": "text",
          "text": prompt},
        {"type": "image_url",
          "image_url": {
            "url": image_url}
        }
      ]
    },
  ]
  result = llama32(messages, model_size)
  return result

# %%
print(llama32pi("describe the image in one sentence",
                "https://raw.githubusercontent.com/meta-llama/"
                "llama-models/refs/heads/main/Llama_Repo.jpeg"))
# Out:
# The image depicts three llamas, one of which is purple and wearing a party hat, standing behind a table with a glass of beer on it.

# %%
print(llama32pi("describe the image in one sentence",
                f"data:image/jpeg;base64,{base64_image}"))
# Out:
# The image depicts three llamas, one of which is wearing a party hat, sitting at a table with a glass of orange liquid.

# %% [markdown]
# ## Plant recognition

# %%
disp_image("images/tree.jpg")

# %%
question = ("What kind of plant is this in my garden?"
            "Describe it in a short paragraph.")

# %%
base64_image = encode_image("images/tree.jpg")
result = llama32pi(question, f"data:image/jpg;base64,{base64_image}")
print(result)

# %% [markdown]
# ## Dog breed recognition

# %%
disp_image("images/ww1.jpg")

# %%
question = (("What dog breed is this? Describe in one paragraph,"
             "and 3-5 short bullet points"))
base64_image = encode_image("images/ww1.jpg")
result = llama32pi(question, f"data:image/jpg;base64,{base64_image}")
print(result)

# %%
disp_image("images/ww2.png")

# %%
base64_image = encode_image("images/ww2.png")
result = llama32pi(question, f"data:image/png;base64,{base64_image}")
print(result)

# %% [markdown]
# ## Tire pressure warning

# %%
disp_image("images/tire_pressure.png")

# %%
question = (("What's the problem this is about?"
             " What should be good numbers?"))

# %%
base64_image = encode_image("images/tire_pressure.png")
result = llama32pi(question, f"data:image/png;base64,{base64_image}")
print(result)
